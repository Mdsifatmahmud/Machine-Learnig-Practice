# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyreadstat as ps

# %%
df = pd.read_excel(r'stocks.xlsx',header=[0,1],index_col=0)
df
# Out:
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %%
df.stack()
# Out:
# C:\Users\MAHMUD\AppData\Local\Temp\ipykernel_17148\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#                       Price  Price to earnings ratio (P/E)
#            Company
# 2017-06-05 Facebook     155                          37.10
#            Google       955                          32.00
#            Microsoft     66                          30.31
# 2017-06-06 Facebook     150                          36.98
#            Google       987                          31.30
#            Microsoft     69                          30.56
# 2017-06-07 Facebook     153                          36.78
#            Google       963                          31.70
#            Microsoft     62                          30.46
# ...

# %%
df.stack(level=0)
# Out:
# C:\Users\MAHMUD\AppData\Local\Temp\ipykernel_17148\4116294391.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)
# Company                                   Facebook  Google  Microsoft
# 2017-06-05 Price                            155.00   955.0      66.00
#            Price to earnings ratio (P/E)     37.10    32.0      30.31
# 2017-06-06 Price                            150.00   987.0      69.00
#            Price to earnings ratio (P/E)     36.98    31.3      30.56
# 2017-06-07 Price                            153.00   963.0      62.00
#            Price to earnings ratio (P/E)     36.78    31.7      30.46
# 2017-06-08 Price                            155.00  1000.0      61.00
#            Price to earnings ratio (P/E)     36.11    31.2      30.11
# ...

# %% [markdown]
# Back To Original DataFrame

# %%
df.stack(level=0).unstack()
df
# Out:
# C:\Users\MAHMUD\AppData\Local\Temp\ipykernel_17148\2235671376.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0).unstack()
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# ...

# %%
data = pd.read_excel(r'stocks_3_levels.xlsx',header=[0,1],index_col=0)
data
# Out:
#         Price Ratios                                                   \
#                Price Price.1    Price.2 Price to earnings ratio (P/E)
# Company     Facebook  Google  Microsoft                      Facebook
# Q1 2016          155     955         66                          37.1
# Q2 2016          150     987         69                         36.98
# Q3 2016          153     963         62                         36.78
# Q4 2016          155    1000         61                         36.11
# Q1 2017          156    1012         66                         37.07
#
#                                                                          \
#         Price to earnings ratio (P/E).1 Price to earnings ratio (P/E).2
# Company                          Google                       Microsoft
# Q1 2016                              32                           30.31
# Q2 2016                            31.3                           30.56
# ...

# %%
data.stack(level=1)
# Out:
# C:\Users\MAHMUD\AppData\Local\Temp\ipykernel_17148\959041612.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   data.stack(level=1)
#                                         Price Ratios Income Statement
# Company Net Profit                               NaN         Facebook
#         Net Profit.1                             NaN           Google
#         Net Profit.2                             NaN        Microsoft
#         Net Sales                                NaN         Facebook
#         Net Sales.1                              NaN           Google
# ...                                              ...              ...
# Q1 2017 Price to earnings ratio (P/E)          37.07              NaN
#         Price to earnings ratio (P/E).1           30              NaN
# ...

# %%
data.stack(level=0)
# Out:
# C:\Users\MAHMUD\AppData\Local\Temp\ipykernel_17148\983712724.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   data.stack(level=0)
#                              Price Price.1    Price.2  \
# Company Income Statement       NaN     NaN        NaN
#         Price Ratios      Facebook  Google  Microsoft
# Q1 2016 Income Statement       NaN     NaN        NaN
#         Price Ratios           155     955         66
# Q2 2016 Income Statement       NaN     NaN        NaN
#         Price Ratios           150     987         69
# Q3 2016 Income Statement       NaN     NaN        NaN
#         Price Ratios           153     963         62
# Q4 2016 Income Statement       NaN     NaN        NaN
#         Price Ratios           155    1000         61
# ...

# %%
tb = pd.read_excel(r'survey.xlsx',header=[0,1],index_col=0)
tb
# Out:
# Name   Nationality     Sex Age Handedness
# Kathy          USA  Female  23      Right
# Linda          USA  Female  18      Right
# Peter          USA    Male  19      Right
# John           USA    Male  22       Left
# Fatima   Bangadesh  Female  31       Left
# Kadir    Bangadesh    Male  25       Left
# Dhaval       India    Male  35       Left
# Sudhir       India    Male  31       Left
# Parvir       India    Male  37      Right
# Yan          China  Female  52      Right
# Juan         China  Female  58       Left
# Liang        China    Male  43       Left

# %%
tb.columns = tb.columns.get_level_values(0)
pd.crosstab(tb.Nationality, tb.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      2

# %%
pd.crosstab(tb.Sex, tb.Handedness, margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      2    4
# Male           5      2    7
# All            7      4   11

# %% [markdown]
# Normalised Value

# %%
pd.crosstab(tb.Sex, tb.Handedness, normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.500000  0.500000
# Male        0.714286  0.285714

# %%
pd.crosstab([tb.Sex],[tb.Handedness], values=tb.Age, aggfunc= np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   35.0
# Male        31.2   28.0
