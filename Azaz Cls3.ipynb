# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r'werather_sifat.xlsx')
print(data)
# Out:
#    Unnamed: 0       date      city  temperature  humidity
# 0           0 2017-01-05  new york           65        56
# 1           1 2017-02-05  new york           66        58
# 2           2 2017-03-05  new york           68        60
# 3           3 2017-01-05    mumbai           75        80
# 4           4 2017-02-05    mumbai           78        83
# 5           5 2017-03-05    mumbai           82        85
# 6           6 2017-01-05   beijing           80        26
# 7           7 2017-02-05   beijing           77        30
# 8           8 2017-03-05   beijing           79        35

# %%
import pyreadstat as ps

# %%
df = pd.read_spss(r"Bangladesh_Pregnancy.sav")
df.head()
# Out:
#             CASEID V000  V001  V012   V013                 V020      V024  \
# 0         1   1  3  BD8   1.0  46.0  45-49  Ever married sample  Barishal
# 1         1   4  2  BD8   1.0  49.0  45-49  Ever married sample  Barishal
# 2         1   7  3  BD8   1.0  27.0  25-29  Ever married sample  Barishal
# 3         1  10  2  BD8   1.0  40.0  40-44  Ever married sample  Barishal
# 4         1  13  2  BD8   1.0  49.0  45-49  Ever married sample  Barishal
#
#     V025       V106 V119  ... M15$1   B4$01 M17$1  M34$1 HW2$1 HW3$1  \
# 0  Urban     Higher  Yes  ...   NaN    Male   NaN    NaN   NaN   NaN
# 1  Urban  Secondary  Yes  ...   NaN    Male   NaN    NaN   NaN   NaN
# 2  Urban  Secondary  Yes  ...   NaN    Male   NaN    NaN   NaN   NaN
# 3  Urban    Primary  Yes  ...   NaN    Male   NaN    NaN   NaN   NaN
# 4  Urban    Primary  Yes  ...   NaN  Female   NaN    NaN   NaN   NaN
#
#         S904 B8$01 B20$01 S435BH$1
# 0     Higher  16.0    9.0      NaN
# ...
